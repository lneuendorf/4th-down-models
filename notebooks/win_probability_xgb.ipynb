# %%
import json
import re
from os.path import join
import os

import pandas as pd
import numpy as np
from tqdm import tqdm
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import optuna
from sklearn.metrics import log_loss, mean_squared_error

import cfbd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

with open('../config.json') as f:
    configuration = cfbd.Configuration(
        access_token = json.load(f)['CFBD_API_KEY']
    )

# %% [markdown]
# ## 1. Load the Data

# %%
YEARS = range(2023, 2024)
DATA_DIR = '../data'

# %%
def convert_to_snake_case(cols):
    cols_new = []
    for c in cols:
        s1 = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', c)
        cols_new.append(re.sub('([a-z0-9])([A-Z])', r'\1_\2', s1).lower())
    return cols_new

# %%
# Load games data
all_dfs = []
id_cols = ['id', 'season', 'week', 'season_type', 'completed', 'neutral_site', 'venue_id']
home_cols = ['home_id', 'home_team', 'home_conference', 'home_division', 'home_points', 'home_pregame_elo']
away_cols = ['away_id', 'away_team', 'away_conference', 'away_division', 'away_points', 'away_pregame_elo']

games_dir = join(DATA_DIR, 'games')
if not os.path.exists(games_dir):
    os.makedirs(games_dir)


for year in YEARS:
    file_path = join(games_dir, f'{year}.parquet')
    if os.path.exists(file_path):
        print(f'Reading {file_path} from cached data')
        df_tmp = pd.read_parquet(file_path)
    else:
        print(f'Fetching {year} games data from CFBD API')
        with cfbd.ApiClient(configuration) as api_client:
            api_instance = cfbd.GamesApi(api_client)
            data = api_instance.get_games(year=year)
        df_tmp = pd.DataFrame([val.to_dict() for val in data])
        df_tmp.columns = convert_to_snake_case(df_tmp.columns)
        df_tmp = df_tmp[id_cols + [
                            'home_id','home_team','home_conference','home_classification','home_points','home_pregame_elo',
                            'away_id','away_team','away_conference','away_classification','away_points','away_pregame_elo']]
        df_tmp['season_type'] = df_tmp['season_type'].apply(lambda x: x.value)
        df_tmp = df_tmp.assign(
            home_division=df_tmp['home_classification'].apply(lambda x: x.value if x is not None else None),
            away_division=df_tmp['away_classification'].apply(lambda x: x.value if x is not None else None)
        ).drop(columns=['home_classification','away_classification'])
        df_tmp = df_tmp[id_cols + home_cols + away_cols]
        df_tmp.to_parquet(file_path)
    all_dfs.append(df_tmp)
del df_tmp

df_games = pd.concat(all_dfs, ignore_index=True).reset_index(drop=True)
df_games.head()
# Out:
# Reading ../data/games/2023.parquet from cached data
#           id  season  week season_type  completed  neutral_site  venue_id  \
# 0  401525434    2023     1     regular       True          True    3504.0
# 1  401540199    2023     1     regular       True          True    3689.0
# 2  401520145    2023     1     regular       True         False    3662.0
# 3  401525450    2023     1     regular       True         False    3601.0
# 4  401540628    2023     1     regular       True         False    4419.0
#
#    home_id           home_team   home_conference home_division  home_points  \
# 0       87          Notre Dame  FBS Independents           fbs         42.0
# 1     2382              Mercer          Southern           fcs         17.0
# 2       55  Jacksonville State    Conference USA           fbs         17.0
# 3      166    New Mexico State    Conference USA           fbs         30.0
# 4      399             UAlbany               CAA           fcs         34.0
#
#    home_pregame_elo  away_id      away_team    away_conference away_division  \
# 0            1733.0     2426           Navy  American Athletic           fbs
# 1               NaN     2453  North Alabama                UAC           fcs
# 2            1500.0     2638           UTEP     Conference USA           fbs
# 3            1322.0      113  Massachusetts   FBS Independents           fbs
# 4               NaN     2230        Fordham            Patriot           fcs
#
#    away_points  away_pregame_elo
# 0          3.0            1471.0
# 1          7.0               NaN
# 2         14.0            1369.0
# 3         41.0            1074.0
# 4         13.0               NaN

# %%
# Load plays data
all_dfs = []
cols = ['id', 'drive_id', 'game_id', 'drive_number', 'play_number', 'offense',
       'offense_conference', 'offense_score', 'defense', 'home', 'away',
       'defense_conference', 'defense_score', 'period', 'offense_timeouts',
       'defense_timeouts', 'yardline', 'yards_to_goal', 'down', 'distance',
       'yards_gained', 'scoring', 'play_type', 'play_text', 'ppa',
       'clock_minutes', 'clock_seconds']

plays_dir = join(DATA_DIR, 'plays')
if not os.path.exists(plays_dir):
    os.makedirs(plays_dir)

for year in YEARS:
    season_file_path = join(plays_dir, f'{year}.parquet')
    
    if os.path.exists(season_file_path):
        print(f'Reading {season_file_path} from cached data')
        df_season_plays = pd.read_parquet(season_file_path)
    else:
        print(f'Fetching all weeks' plays data for {year} from CFBD API')
        weeks = df_games.query('season == @year').week.unique().tolist()

        season_dfs = []
        for week in weeks:
            print(f'Fetching {year} plays data for week {week} from CFBD API')
            with cfbd.ApiClient(configuration) as api_client:
                api_instance = cfbd.PlaysApi(api_client)
                data = api_instance.get_plays(year=year, week=week)
            df_tmp = pd.DataFrame([val.to_dict() for val in data])
            df_tmp.columns = convert_to_snake_case(df_tmp.columns)

            df_tmp['clock_minutes'] = df_tmp['clock'].apply(lambda x: x['minutes'])
            df_tmp['clock_seconds'] = df_tmp['clock'].apply(lambda x: x['seconds'])
            df_tmp.drop(columns=['clock'], inplace=True)

            df_tmp = df_tmp[cols]
            season_dfs.append(df_tmp)
        
        df_season_plays = pd.concat(season_dfs, ignore_index=True).reset_index(drop=True)
        
        df_season_plays.to_parquet(season_file_path)
        print(f'Saved plays data for {year} to {season_file_path}')
        del df_season_plays, season_dfs, df_tmp

    all_dfs.append(df_season_plays)
    
df_plays = pd.concat(all_dfs, ignore_index=True).reset_index(drop=True)
df_plays.head()
# Out:
# Reading ../data/plays/2023.parquet from cached data
#                    id     drive_id    game_id  drive_number  play_number  \
# 0  401540244104995401  40154024433  401540244            22            6
# 1  401540244104994901  40154024433  401540244            22            5
# 2  401540244104977803  40154024433  401540244            22            4
# 3  401540244104977802  40154024433  401540244            22            3
# 4  401540244104977801  40154024433  401540244            22            2
#
#   offense offense_conference  offense_score defense   home   away  \
# 0   Idaho            Big Sky             42   Lamar  Lamar  Idaho
# 1   Idaho            Big Sky             42   Lamar  Lamar  Idaho
# 2   Idaho            Big Sky             42   Lamar  Lamar  Idaho
# 3   Idaho            Big Sky             42   Lamar  Lamar  Idaho
# 4   Idaho            Big Sky             42   Lamar  Lamar  Idaho
#
#   defense_conference  defense_score  period  offense_timeouts  \
# 0          Southland             17       4               3.0
# 1          Southland             17       4               3.0
# 2          Southland             17       4               3.0
# 3          Southland             17       4               3.0
# 4          Southland             17       4               3.0
#
#    defense_timeouts  yardline  yards_to_goal  down  distance  yards_gained  \
# 0               3.0        67             67     3        28             5
# 1               3.0        66             66     2        27            -1
# 2               3.0        64             64     1        25            -2
# 3               3.0        49             49     1        10           -15
# 4               3.0        65             65     3        10            16
#
#    scoring play_type                                          play_text  \
# 0    False      Rush        Carlos Matheney run for 5 yds to the LAM 39
# 1    False      Rush  Carlos Matheney run for a loss of 1 yard to th...
# 2    False      Rush  Carlos Matheney run for a loss of 2 yards to t...
# 3    False      Rush  Idaho Penalty, face mask (15 yards) (Carlos Ma...
# 4    False      Rush  Jack Layne run for 16 yds to the LAM 49 for a ...
#
#         ppa  clock_minutes  clock_seconds
# 0  0.003424              0             45
# 1 -0.145843              0             50
# 2 -0.464241              2             21
# 3 -3.323128              2             21
# 4  3.095490              2             21

# %%
elos = []
for year in YEARS:
    elos.append(pd.read_parquet(join(DATA_DIR, 'elo', f'{year}.parquet')))
df_elos = pd.concat(elos, ignore_index=True).reset_index(drop=True)
df_elos.head()
# Out:
#    season  week  team_id    team division          elo
# 0    2023     1        2  Auburn      fbs  2461.917368
# 1    2023     1        2  Auburn      fbs  2461.917368
# 2    2023     2        2  Auburn      fbs  2386.104340
# 3    2023     3        2  Auburn      fbs  2414.568283
# 4    2023     4        2  Auburn      fbs  2430.356172

# %% [markdown]
# ## 2. Join and Filter the Data

# %%
# Merge games and plays data
cols = ['id', 'season', 'week', 'season_type', 'completed', 'neutral_site', 'venue_id', 
        'home_team','home_id','home_points', 
        'away_team','away_id', 'away_points']

id_cols = ['game_id', 'drive_id', 'play_id', 'drive_number', 'play_number','season', 'week']

elo_cols = ['season', 'week', 'division', 'team_id', 'elo']

df = (
    df_games[cols].merge(df_plays, left_on='id', right_on='game_id', suffixes=('_game', ''))
    .drop(columns=['id_game'])
    .rename(columns={'id': 'play_id'})
    .merge(
        df_elos[elo_cols].rename(columns={'team_id': 'home_id', 'division': 'home_division', 'elo': 'home_pregame_elo'}),
        on=['season', 'week', 'home_id'],
        how='left'
    )
    .merge(
        df_elos[elo_cols].rename(columns={'team_id': 'away_id', 'division': 'away_division', 'elo': 'away_pregame_elo'}),
        on=['season', 'week', 'away_id'],
        how='left'
    )
)
df = df[id_cols + [c for c in df.columns if c not in id_cols]]
df.head()
# Out:
#      game_id     drive_id             play_id  drive_number  play_number  \
# 0  401525434  40152543416  401525434104996901            16            8
# 1  401525434  40152543416  401525434104996901            16            8
# 2  401525434  40152543416  401525434104996901            16            8
# 3  401525434  40152543416  401525434104989901            16            7
# 4  401525434  40152543416  401525434104989901            16            7
#
#    season  week season_type  completed  neutral_site  venue_id   home_team  \
# 0    2023     1     regular       True          True    3504.0  Notre Dame
# 1    2023     1     regular       True          True    3504.0  Notre Dame
# 2    2023     1     regular       True          True    3504.0  Notre Dame
# 3    2023     1     regular       True          True    3504.0  Notre Dame
# 4    2023     1     regular       True          True    3504.0  Notre Dame
#
#    home_id  home_points away_team  away_id  away_points     offense  \
# 0       87         42.0      Navy     2426          3.0  Notre Dame
# 1       87         42.0      Navy     2426          3.0  Notre Dame
# 2       87         42.0      Navy     2426          3.0  Notre Dame
# 3       87         42.0      Navy     2426          3.0  Notre Dame
# 4       87         42.0      Navy     2426          3.0  Notre Dame
#
#   offense_conference  offense_score defense        home  away  \
# 0   FBS Independents             42    Navy  Notre Dame  Navy
# 1   FBS Independents             42    Navy  Notre Dame  Navy
# 2   FBS Independents             42    Navy  Notre Dame  Navy
# 3   FBS Independents             42    Navy  Notre Dame  Navy
# 4   FBS Independents             42    Navy  Notre Dame  Navy
#
#   defense_conference  defense_score  period  offense_timeouts  \
# 0  American Athletic              3       4               2.0
# 1  American Athletic              3       4               2.0
# 2  American Athletic              3       4               2.0
# 3  American Athletic              3       4               2.0
# 4  American Athletic              3       4               2.0
#
#    defense_timeouts  yardline  yards_to_goal  down  distance  yards_gained  \
# 0               1.0        40             60     2         8            -2
# 1               1.0        40             60     2         8            -2
# 2               1.0        40             60     2         8            -2
# 3               1.0        38             62     1        10             2
# 4               1.0        38             62     1        10             2
#
#    scoring              play_type  \
# 0    False  Fumble Recovery (Own)
# 1    False  Fumble Recovery (Own)
# 2    False  Fumble Recovery (Own)
# 3    False         Pass Reception
# 4    False         Pass Reception
#
#                                            play_text       ppa  clock_minutes  \
# 0  Chris Tyree run for a loss of 2 yards to the N... -1.116190              0
# 1  Chris Tyree run for a loss of 2 yards to the N... -1.116190              0
# 2  Chris Tyree run for a loss of 2 yards to the N... -1.116190              0
# 3  Steve Angeli pass complete to Rico Flores for ... -0.665638              1
# 4  Steve Angeli pass complete to Rico Flores for ... -0.665638              1
#
#    clock_seconds home_division  home_pregame_elo away_division  \
# 0             30           fbs       3136.803907           fbs
# 1             30           fbs       3136.803907           fbs
# 2             30           fbs       3136.803907           fbs
# 3              0           fbs       3136.803907           fbs
# 4              0           fbs       3136.803907           fbs
#
#    away_pregame_elo
# 0       1873.803009
# 1       1873.803009
# 2       1873.803009
# 3       1873.803009
# 4       1873.803009

# %%
# Filter out overtime plays
df = df.query('period <= 4')

# Game must be completed
df = df.query('completed == True')

# %%
df.isna().sum()
# Out:
# game_id                   0
# drive_id                  0
# play_id                   0
# drive_number              0
# play_number               0
# season                    0
# week                      0
# season_type               0
# completed                 0
# neutral_site              0
# venue_id                  0
# home_team                 0
# home_id                   0
# home_points               0
# away_team                 0
# away_id                   0
# away_points               0
# offense                   0
# offense_conference     1062
# offense_score             0
# defense                   0
# home                      0
# away                      0
# defense_conference     1232
# defense_score             0
# period                    0
# offense_timeouts          0
# defense_timeouts          0
# yardline                  0
# yards_to_goal             0
# down                      0
# distance                  0
# yards_gained              0
# scoring                   0
# play_type                 0
# play_text               738
# ppa                   75608
# clock_minutes             0
# clock_seconds             0
# home_division             0
# home_pregame_elo          0
# away_division             0
# away_pregame_elo          0
# dtype: int64

# %% [markdown]
# ## 3. Feature Engineering

# %%
df = df.assign(
    pct_game_played = (((df['period'] - 1) * 15 * 60) + ((15 * 60) - (df['clock_minutes'] * 60 + df['clock_seconds']))) / (4 * 15 * 60),
    score_diff = df['offense_score'] - df['defense_score'],
    home_team = np.select([df.neutral_site, df.offense == df.home], [0, 1], default=-1),
    pregame_elo_diff = np.where(df['offense'] == df['home'], df['home_pregame_elo'] - df['away_pregame_elo'], df['away_pregame_elo'] - df['home_pregame_elo']),
    pregame_offense_elo = np.where(df['offense'] == df['home'], df['home_pregame_elo'], df['away_pregame_elo']),
    pregame_defense_elo = np.where(df['offense'] == df['home'], df['away_pregame_elo'], df['home_pregame_elo']),
    offense_division = np.where(df['offense'] == df['home'], df['home_division'], df['away_division']),
    defense_division = np.where(df['offense'] == df['home'], df['away_division'], df['home_division']),
    score_diff_final = np.where(df['offense'] == df['home'], df['home_points'] - df['away_points'], df['away_points'] - df['home_points'])
)

df.head()
# Out:
#      game_id     drive_id             play_id  drive_number  play_number  \
# 0  401525434  40152543416  401525434104996901            16            8
# 1  401525434  40152543416  401525434104996901            16            8
# 2  401525434  40152543416  401525434104996901            16            8
# 3  401525434  40152543416  401525434104989901            16            7
# 4  401525434  40152543416  401525434104989901            16            7
#
#    season  week season_type  completed  neutral_site  venue_id  home_team  \
# 0    2023     1     regular       True          True    3504.0          0
# 1    2023     1     regular       True          True    3504.0          0
# 2    2023     1     regular       True          True    3504.0          0
# 3    2023     1     regular       True          True    3504.0          0
# 4    2023     1     regular       True          True    3504.0          0
#
#    home_id  home_points away_team  away_id  away_points     offense  \
# 0       87         42.0      Navy     2426          3.0  Notre Dame
# 1       87         42.0      Navy     2426          3.0  Notre Dame
# 2       87         42.0      Navy     2426          3.0  Notre Dame
# 3       87         42.0      Navy     2426          3.0  Notre Dame
# 4       87         42.0      Navy     2426          3.0  Notre Dame
#
#   offense_conference  offense_score defense        home  away  \
# 0   FBS Independents             42    Navy  Notre Dame  Navy
# 1   FBS Independents             42    Navy  Notre Dame  Navy
# 2   FBS Independents             42    Navy  Notre Dame  Navy
# 3   FBS Independents             42    Navy  Notre Dame  Navy
# 4   FBS Independents             42    Navy  Notre Dame  Navy
#
#   defense_conference  defense_score  period  offense_timeouts  \
# 0  American Athletic              3       4               2.0
# 1  American Athletic              3       4               2.0
# 2  American Athletic              3       4               2.0
# 3  American Athletic              3       4               2.0
# 4  American Athletic              3       4               2.0
#
#    defense_timeouts  yardline  yards_to_goal  down  distance  yards_gained  \
# 0               1.0        40             60     2         8            -2
# 1               1.0        40             60     2         8            -2
# 2               1.0        40             60     2         8            -2
# 3               1.0        38             62     1        10             2
# 4               1.0        38             62     1        10             2
#
#    scoring              play_type  \
# 0    False  Fumble Recovery (Own)
# 1    False  Fumble Recovery (Own)
# 2    False  Fumble Recovery (Own)
# 3    False         Pass Reception
# 4    False         Pass Reception
#
#                                            play_text       ppa  clock_minutes  \
# 0  Chris Tyree run for a loss of 2 yards to the N... -1.116190              0
# 1  Chris Tyree run for a loss of 2 yards to the N... -1.116190              0
# 2  Chris Tyree run for a loss of 2 yards to the N... -1.116190              0
# 3  Steve Angeli pass complete to Rico Flores for ... -0.665638              1
# 4  Steve Angeli pass complete to Rico Flores for ... -0.665638              1
#
#    clock_seconds home_division  home_pregame_elo away_division  \
# 0             30           fbs       3136.803907           fbs
# 1             30           fbs       3136.803907           fbs
# 2             30           fbs       3136.803907           fbs
# 3              0           fbs       3136.803907           fbs
# 4              0           fbs       3136.803907           fbs
#
#    away_pregame_elo  pct_game_played  score_diff  pregame_elo_diff  \
# 0       1873.803009         0.991667          39       1263.000898
# 1       1873.803009         0.991667          39       1263.000898
# 2       1873.803009         0.991667          39       1263.000898
# 3       1873.803009         0.983333          39       1263.000898
# 4       1873.803009         0.983333          39       1263.000898
#
#    pregame_offense_elo  pregame_defense_elo offense_division defense_division  \
# 0          3136.803907          1873.803009              fbs              fbs
# 1          3136.803907          1873.803009              fbs              fbs
# 2          3136.803907          1873.803009              fbs              fbs
# 3          3136.803907          1873.803009              fbs              fbs
# 4          3136.803907          1873.803009              fbs              fbs
#
#    score_diff_final
# 0              39.0
# 1              39.0
# 2              39.0
# 3              39.0
# 4              39.0

# %%
df.columns
# Out:
# Index(['game_id', 'drive_id', 'play_id', 'drive_number', 'play_number',
#        'season', 'week', 'season_type', 'completed', 'neutral_site',
#        'venue_id', 'home_team', 'home_id', 'home_points', 'away_team',
#        'away_id', 'away_points', 'offense', 'offense_conference',
#        'offense_score', 'defense', 'home', 'away', 'defense_conference',
#        'defense_score', 'period', 'offense_timeouts', 'defense_timeouts',
#        'yardline', 'yards_to_goal', 'down', 'distance', 'yards_gained',
#        'scoring', 'play_type', 'play_text', 'ppa', 'clock_minutes',
#        'clock_seconds', 'home_division', 'home_pregame_elo', 'away_division',
#        'away_pregame_elo', 'pct_game_played', 'score_diff', 'pregame_elo_diff',
#        'pregame_offense_elo', 'pregame_defense_elo', 'offense_division',
#        'defense_division', 'score_diff_final'],
#       dtype='object')

# %% [markdown]
# ## 4. Final Data

# %%
cols = ['game_id', 'drive_id', 'play_id', 'season', 'week', 'season_type', 'venue_id', 
        'offense', 'offense_conference', 'offense_division', 
        'defense', 'defense_conference', 'defense_division', 
        'score_diff', 'pregame_elo_diff', 'pregame_offense_elo', 'pregame_defense_elo', 'pct_game_played',
        'offense_timeouts', 'defense_timeouts', 'home_team',
        'score_diff_final']

#TODO: remove filtering for FBS only?
df = df[cols].query('offense_division == 'fbs' & defense_division == 'fbs'').reset_index(drop=True)
df.head()
# Out:
#      game_id     drive_id             play_id  season  week season_type  \
# 0  401525434  40152543416  401525434104996901    2023     1     regular
# 1  401525434  40152543416  401525434104996901    2023     1     regular
# 2  401525434  40152543416  401525434104996901    2023     1     regular
# 3  401525434  40152543416  401525434104989901    2023     1     regular
# 4  401525434  40152543416  401525434104989901    2023     1     regular
#
#    venue_id     offense offense_conference offense_division defense  \
# 0    3504.0  Notre Dame   FBS Independents              fbs    Navy
# 1    3504.0  Notre Dame   FBS Independents              fbs    Navy
# 2    3504.0  Notre Dame   FBS Independents              fbs    Navy
# 3    3504.0  Notre Dame   FBS Independents              fbs    Navy
# 4    3504.0  Notre Dame   FBS Independents              fbs    Navy
#
#   defense_conference defense_division  score_diff  pregame_elo_diff  \
# 0  American Athletic              fbs          39       1263.000898
# 1  American Athletic              fbs          39       1263.000898
# 2  American Athletic              fbs          39       1263.000898
# 3  American Athletic              fbs          39       1263.000898
# 4  American Athletic              fbs          39       1263.000898
#
#    pregame_offense_elo  pregame_defense_elo  pct_game_played  \
# 0          3136.803907          1873.803009         0.991667
# 1          3136.803907          1873.803009         0.991667
# 2          3136.803907          1873.803009         0.991667
# 3          3136.803907          1873.803009         0.983333
# 4          3136.803907          1873.803009         0.983333
#
#    offense_timeouts  defense_timeouts  home_team  score_diff_final
# 0               2.0               1.0          0              39.0
# 1               2.0               1.0          0              39.0
# 2               2.0               1.0          0              39.0
# 3               2.0               1.0          0              39.0
# 4               2.0               1.0          0              39.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.kdeplot(df.query('score_diff_final >= 0').score_diff_final, fill=True, color='blue')
plt.title('KDE Density Plot of score_diff_final')
plt.xlabel('score_diff_final')
plt.ylabel('Density')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.kdeplot(df.score_diff_final, fill=True, color='blue')
plt.title('KDE Density Plot of score_diff_final')
plt.xlabel('score_diff_final')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ## 5. Make the model

# %%
df.head()
# Out:
#      game_id     drive_id             play_id  season  week season_type  \
# 0  401525434  40152543416  401525434104996901    2023     1     regular
# 1  401525434  40152543416  401525434104996901    2023     1     regular
# 2  401525434  40152543416  401525434104996901    2023     1     regular
# 3  401525434  40152543416  401525434104989901    2023     1     regular
# 4  401525434  40152543416  401525434104989901    2023     1     regular
#
#    venue_id     offense offense_conference offense_division defense  \
# 0    3504.0  Notre Dame   FBS Independents              fbs    Navy
# 1    3504.0  Notre Dame   FBS Independents              fbs    Navy
# 2    3504.0  Notre Dame   FBS Independents              fbs    Navy
# 3    3504.0  Notre Dame   FBS Independents              fbs    Navy
# 4    3504.0  Notre Dame   FBS Independents              fbs    Navy
#
#   defense_conference defense_division  score_diff  pregame_elo_diff  \
# 0  American Athletic              fbs          39       1263.000898
# 1  American Athletic              fbs          39       1263.000898
# 2  American Athletic              fbs          39       1263.000898
# 3  American Athletic              fbs          39       1263.000898
# 4  American Athletic              fbs          39       1263.000898
#
#    pregame_offense_elo  pregame_defense_elo  pct_game_played  \
# 0          3136.803907          1873.803009         0.991667
# 1          3136.803907          1873.803009         0.991667
# 2          3136.803907          1873.803009         0.991667
# 3          3136.803907          1873.803009         0.983333
# 4          3136.803907          1873.803009         0.983333
#
#    offense_timeouts  defense_timeouts  home_team  score_diff_final
# 0               2.0               1.0          0              39.0
# 1               2.0               1.0          0              39.0
# 2               2.0               1.0          0              39.0
# 3               2.0               1.0          0              39.0
# 4               2.0               1.0          0              39.0

# %%
df.head()
# Out:
#      game_id     drive_id             play_id  season  week season_type  \
# 0  401525434  40152543416  401525434104996901    2023     1     regular
# 1  401525434  40152543416  401525434104996901    2023     1     regular
# 2  401525434  40152543416  401525434104996901    2023     1     regular
# 3  401525434  40152543416  401525434104989901    2023     1     regular
# 4  401525434  40152543416  401525434104989901    2023     1     regular
#
#    venue_id     offense offense_conference offense_division defense  \
# 0    3504.0  Notre Dame   FBS Independents              fbs    Navy
# 1    3504.0  Notre Dame   FBS Independents              fbs    Navy
# 2    3504.0  Notre Dame   FBS Independents              fbs    Navy
# 3    3504.0  Notre Dame   FBS Independents              fbs    Navy
# 4    3504.0  Notre Dame   FBS Independents              fbs    Navy
#
#   defense_conference defense_division  score_diff  pregame_elo_diff  \
# 0  American Athletic              fbs          39       1263.000898
# 1  American Athletic              fbs          39       1263.000898
# 2  American Athletic              fbs          39       1263.000898
# 3  American Athletic              fbs          39       1263.000898
# 4  American Athletic              fbs          39       1263.000898
#
#    pregame_offense_elo  pregame_defense_elo  pct_game_played  \
# 0          3136.803907          1873.803009         0.991667
# 1          3136.803907          1873.803009         0.991667
# 2          3136.803907          1873.803009         0.991667
# 3          3136.803907          1873.803009         0.983333
# 4          3136.803907          1873.803009         0.983333
#
#    offense_timeouts  defense_timeouts  home_team  score_diff_final
# 0               2.0               1.0          0              39.0
# 1               2.0               1.0          0              39.0
# 2               2.0               1.0          0              39.0
# 3               2.0               1.0          0              39.0
# 4               2.0               1.0          0              39.0

# %%
data = df[['game_id','score_diff','pregame_elo_diff','pregame_defense_elo','pct_game_played','home_team']]
target = df[['score_diff_final']]

# Split into 80-20 train val set by game_id
game_ids = df.game_id.unique()
game_ids_train, game_ids_test = train_test_split(game_ids, test_size=0.2, random_state=42)

data_train = data[data.game_id.isin(game_ids_train)]
target_train = target[target.index.isin(data_train.index)]

data_test = data[data.game_id.isin(game_ids_test)].drop(columns='game_id')
target_test = target[target.index.isin(data_test.index)]

# %%
optuna.logging.set_verbosity(optuna.logging.INFO)

def objective(trial):
    game_ids = data_train.game_id.unique()
    game_ids_train, game_ids_valid = train_test_split(game_ids, test_size=0.2, random_state=42)
  
    train_x = data_train[data_train.game_id.isin(game_ids_train)].drop(columns='game_id')
    valid_x = data_train[data_train.game_id.isin(game_ids_valid)].drop(columns='game_id')
    train_y = target_train[target_train.index.isin(train_x.index)].values.ravel()
    valid_y = target_train[target_train.index.isin(valid_x.index)].values.ravel()
  
    dtrain = xgb.DMatrix(train_x, label=train_y)
    dvalid = xgb.DMatrix(valid_x, label=valid_y)
  
    param = {
        # "verbosity": 0,
        "nthread": -1,
        "objective": "reg:squarederror",
        "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
        "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
        "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
        "subsample": trial.suggest_float("subsample", 0.2, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 1.0),
    }
  
    if param["booster"] in ["gbtree", "dart"]:
        param["max_depth"] = trial.suggest_int("max_depth", 3, 9, step=2)
        param["min_child_weight"] = trial.suggest_float("min_child_weight", .5, 5, step=.5)
        param["eta"] = trial.suggest_float("eta", .01, 1.0, log=True)
        param["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
        param["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])
  
    if param["booster"] == "dart":
        param["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
        param["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
        param["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
        param["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)
    
    if param["booster"] == "gblinear":
        param["feature_selector"] = trial.suggest_categorical("feature_selector", ["cyclic", "shuffle"])
        param["updater"] = trial.suggest_categorical("updater", ["shotgun", "coord_descent"])
    
    bst = xgb.train(
        param, 
        dtrain,
        num_boost_round=1000,
        evals=[(dvalid, "eval")],
        early_stopping_rounds=10,
        verbose_eval=False
    )
    preds = bst.predict(dvalid)
  
    return mean_squared_error(valid_y, preds)

storage = "sqlite:///studies/wp_hyperopt.db"
study = optuna.create_study(
    study_name="win_probability_hyperopt", 
    storage=storage, 
    direction="minimize", 
    load_if_exists=True
)
study.optimize(objective, n_trials=100)

print("Best parameters:", study.best_params)
print("Best value:", study.best_value)
# Out:
# [I 2025-03-25 21:26:51,457] A new study created in RDB with name: win_probability_hyperopt
# [I 2025-03-25 21:27:45,771] Trial 0 finished with value: 137.35072051999188 and parameters: {'booster': 'dart', 'lambda': 0.33585144600288747, 'alpha': 6.74803728042465e-05, 'subsample': 0.37979033487989194, 'colsample_bytree': 0.8431171417443721, 'max_depth': 7, 'min_child_weight': 3.5, 'eta': 0.015283470851790772, 'gamma': 2.244152699274452e-05, 'grow_policy': 'lossguide', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 0.006056281756437704, 'skip_drop': 0.004190250924947266}. Best is trial 0 with value: 137.35072051999188.
# [I 2025-03-25 21:27:45,951] Trial 1 finished with value: 170.11179350597905 and parameters: {'booster': 'gbtree', 'lambda': 1.0717484053118358e-07, 'alpha': 0.024895458829668086, 'subsample': 0.29446818583944695, 'colsample_bytree': 0.3785405179538292, 'max_depth': 3, 'min_child_weight': 3.5, 'eta': 0.07583281768496512, 'gamma': 1.9747955495054082e-08, 'grow_policy': 'lossguide'}. Best is trial 0 with value: 137.35072051999188.
# [I 2025-03-25 21:27:46,054] Trial 2 finished with value: 141.6649365363062 and parameters: {'booster': 'gbtree', 'lambda': 1.8883901032328426e-07, 'alpha': 7.958321399570583e-06, 'subsample': 0.7041545464476842, 'colsample_bytree': 0.9262195364958881, 'max_depth': 5, 'min_child_weight': 1.0, 'eta': 0.482908260642316, 'gamma': 2.9547099851455334e-05, 'grow_policy': 'depthwise'}. Best is trial 0 with value: 137.35072051999188.
# [I 2025-03-25 21
 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.002922720631535427, 'skip_drop': 0.00010374129818623132}. Best is trial 67 with value: 135.46430892632648.
# [I 2025-03-25 22:11:04,513] Trial 77 finished with value: 178.2157484416671 and parameters: {'booster': 'dart', 'lambda': 0.0016937982376373593, 'alpha': 2.776604494595373e-08, 'subsample': 0.28345286965168776, 'colsample_bytree': 0.8388576311521698, 'max_depth': 5, 'min_child_weight': 3.5, 'eta': 0.010069195204187793, 'gamma': 3.8303949119938576e-05, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.05011324088580663, 'skip_drop': 2.5054355730376628e-05}. Best is trial 67 with value: 135.46430892632648.
# [I 2025-03-25 22:11:41,294] Trial 78 finished with value: 136.6680958608088 and parameters: {'booster': 'dart', 'lambda': 8.694093654680197e-06, 'alpha': 1.0922321975377885e-06, 'subsample': 0.3775071488225892, 'colsample_bytree': 0.8077485810961493, 'max_depth': 5, 'min_child_weight': 3.0, 'eta': 0.02090479988511659, 'gamma': 4.988990405583558e-06, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.00015836967118288203, 'skip_drop': 0.0789498668794017}. Best is trial 67 with value: 135.46430892632648.
# [I 2025-03-25 22:12:50,795] Trial 79 finished with value: 142.0221182828891 and parameters: {'booster': 'dart', 'lambda': 3.242339728521866e-05, 'alpha': 1.4883404321185912e-08, 'subsample': 0.3359071632245147, 'colsample_bytree': 0.7774919731500435, 'max_depth': 5, 'min_child_weight': 2.5, 'eta': 0.01413747585739023, 'gamma': 9.89700475414481e-07, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 1.3823037231759422e-07, 'skip_drop': 1.5002117295619673e-06}. Best is trial 67 with value: 135.46430892632648.
# [I 2025-03-25 22:13:15,261] Trial 80 finished with value: 140.98379083853985 and parameters: {'booster': 'dart', 'lambda': 0.0003065323613880794, 'alpha': 3.831063511591949e-08, 'subsample': 0.3942035034940107, 'colsample_bytree': 0.8544934330607384, 'max_depth': 3, 'min_child_weight': 4.5, 'eta': 0.02516152644967148, 'gamma': 1.3112658212993122e-05, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 1.7771476765236292e-05, 'skip_drop': 0.0014463103769554108}. Best is trial 67 with value: 135.46430892632648.
# [I 2025-03-25 22:13:42,629] Trial 81 finished with value: 138.08412085106286 and parameters: {'booster': 'dart', 'lambda': 1.6531493809934578e-05, 'alpha': 0.00022512678844853254, 'subsample': 0.5238902434138899, 'colsample_bytree': 0.9759009297872956, 'max_depth': 7, 'min_child_weight': 3.0, 'eta': 0.020011726713113857, 'gamma': 2.3970438399143796e-07, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.0007313419330517058, 'skip_drop': 9.151080783114177e-05}. Best is trial 67 with value: 135.46430892632648.
# [I 2025-03-25 22:13:42,806] Trial 82 finished with value: 142.25186298078913 and parameters: {'booster': 'gblinear', 'lambda': 5.912748340220185e-06, 'alpha': 6.103823402020413e-07, 'subsample': 0.47821160758672077, 'colsample_bytree': 0.9283201618853777, 'feature_selector': 'cyclic', 'updater': 'coord_descent'}. Best is trial 67 with value: 135.46430892632648.
# [I 2025-03-25 22:13:43,075] Trial 83 finished with value: 196.60390989039215 and parameters: {'booster': 'dart', 'lambda': 2.4665271135131157e-05, 'alpha': 7.180774822763893e-08, 'subsample': 0.5029350435760535, 'colsample_bytree': 0.8751202892771643, 'max_depth': 7, 'min_child_weight': 0.5, 'eta': 0.9266740810936717, 'gamma': 1.15083562356546e-07, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.0048791984569549855, 'skip_drop': 0.006034809530955196}. Best is trial 67 with value: 135.46430892632648.
# [I 2025-03-25 22:13:44,059] Trial 84 finished with value: 137.47012971008888 and parameters: {'booster': 'gbtree', 'lambda': 7.100663061289483e-05, 'alpha': 3.2572398774776497e-07, 'subsample': 0.4303129815385745, 'colsample_bytree': 0.9100693711750754, 'max_depth': 7, 'min_child_weight': 2.5, 'eta': 0.018657674134965954, 'gamma': 2.0634644689313005e-06, 'grow_policy': 'depthwise'}. Best is trial 67 with value: 135.46430892632648.
# [I 2025-03-25 22:13:45,938] Trial 85 finished with value: 130.4257414430552 and parameters: {'booster': 'dart', 'lambda': 2.761871933924673e-06, 'alpha': 3.142219644959631e-06, 'subsample': 0.5409070993493589, 'colsample_bytree': 0.9773215014380134, 'max_depth': 5, 'min_child_weight': 3.5, 'eta': 0
. Best is trial 85 with value: 130.4257414430552.
# [I 2025-03-25 22:13:54,596] Trial 93 finished with value: 135.63739727552831 and parameters: {'booster': 'dart', 'lambda': 3.910872086826579e-06, 'alpha': 1.531430096436289e-07, 'subsample': 0.3547067687738148, 'colsample_bytree': 0.8320345489755591, 'max_depth': 5, 'min_child_weight': 4.5, 'eta': 0.23659020544749673, 'gamma': 8.311724167515027e-06, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 5.384863341207489e-07, 'skip_drop': 0.00025614712014522415}. Best is trial 85 with value: 130.4257414430552.
# [I 2025-03-25 22:13:55,411] Trial 94 finished with value: 134.01930557839245 and parameters: {'booster': 'dart', 'lambda': 3.5849306734477047e-06, 'alpha': 8.077185054723189e-07, 'subsample': 0.35360726211890914, 'colsample_bytree': 0.9200649735260131, 'max_depth': 5, 'min_child_weight': 1.0, 'eta': 0.1966045492852596, 'gamma': 0.000567880061908594, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 5.25533576030455e-07, 'skip_drop': 0.0002619676318711508}. Best is trial 85 with value: 130.4257414430552.
# [I 2025-03-25 22:13:55,520] Trial 95 finished with value: 142.2222704220804 and parameters: {'booster': 'gblinear', 'lambda': 4.553425643027196e-06, 'alpha': 7.412789853286064e-07, 'subsample': 0.3507148292594843, 'colsample_bytree': 0.9205982973740182, 'feature_selector': 'shuffle', 'updater': 'shotgun'}. Best is trial 85 with value: 130.4257414430552.
# [I 2025-03-25 22:13:56,299] Trial 96 finished with value: 142.86376912610564 and parameters: {'booster': 'dart', 'lambda': 1.1691490652237647e-06, 'alpha': 4.242342541845555e-06, 'subsample': 0.515879732877316, 'colsample_bytree': 0.9432350178037334, 'max_depth': 5, 'min_child_weight': 1.0, 'eta': 0.25093313708131215, 'gamma': 0.0005639040340810034, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 6.081287208607941e-07, 'skip_drop': 0.00027763988755800495}. Best is trial 85 with value: 130.4257414430552.
# [I 2025-03-25 22:13:57,633] Trial 97 finished with value: 138.19876135580787 and parameters: {'booster': 'dart', 'lambda': 1.0496188256721905e-05, 'alpha': 1.1449401839230082e-06, 'subsample': 0.6243366703839167, 'colsample_bytree': 0.8959024278496204, 'max_depth': 5, 'min_child_weight': 5.0, 'eta': 0.18105559617632352, 'gamma': 0.001611325273863176, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 2.6594589757681984e-06, 'skip_drop': 0.02756339352952277}. Best is trial 85 with value: 130.4257414430552.
# [I 2025-03-25 22:13:58,114] Trial 98 finished with value: 147.9460932315575 and parameters: {'booster': 'dart', 'lambda': 2.493381692279556e-06, 'alpha': 3.9565321272885145e-07, 'subsample': 0.36612179655936467, 'colsample_bytree': 0.5610274668842876, 'max_depth': 5, 'min_child_weight': 0.5, 'eta': 0.3238191760427464, 'gamma': 0.00015462682759464388, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 4.462519195249511e-07, 'skip_drop': 0.00022302412603850165}. Best is trial 85 with value: 130.4257414430552.
# [I 2025-03-25 22:13:59,465] Trial 99 finished with value: 136.57857281998457 and parameters: {'booster': 'dart', 'lambda': 6.021900587408499e-07, 'alpha': 0.4267888902501867, 'subsample': 0.9364763116124276, 'colsample_bytree': 0.9712902082037183, 'max_depth': 5, 'min_child_weight': 1.0, 'eta': 0.21473390781767696, 'gamma': 0.0012204052457908895, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 7.0696564490789055e-06, 'skip_drop': 0.0024003238576195234}. Best is trial 85 with value: 130.4257414430552.
# Best parameters: {'booster': 'dart', 'lambda': 2.761871933924673e-06, 'alpha': 3.142219644959631e-06, 'subsample': 0.5409070993493589, 'colsample_bytree': 0.9773215014380134, 'max_depth': 5, 'min_child_weight': 3.5, 'eta': 0.21718448853936242, 'gamma': 0.000539604853095497, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 5.1063322519110745e-06, 'skip_drop': 6.0289095676846945e-06}
# Best value: 130.4257414430552
